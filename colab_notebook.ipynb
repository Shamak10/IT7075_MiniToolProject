# %% [markdown]
# # Colab: persistent storage + hosted model access (§3.4, §3.5, §3.8)
# Upload this notebook to https://colab.research.google.com/ and run cell by cell.

# %%
print("Colab environment check OK")
1 + 1

# %% [markdown]
# ## Mount Drive and write a file (§3.4)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = '/content/drive/MyDrive/it7075_persistence_test.txt'
with open(path, 'w') as f:
    f.write('This file should survive a runtime restart.')
print('wrote', path)

# %% [markdown]
# ### Now: Runtime menu -> Restart session. Reconnect, then re-mount Drive and run the next cell to prove persistence.

# %%
from google.colab import drive
drive.mount('/content/drive')
with open('/content/drive/MyDrive/it7075_persistence_test.txt') as f:
    print(f.read())

# %% [markdown]
# ## Hosted model access using Colab Secrets (§3.5)
# Add ANTHROPIC_API_KEY and OPENAI_API_KEY under the key (🔑) icon in the left sidebar -> Secrets, and enable notebook access for each, before running this cell.

# %%
from google.colab import userdata
from anthropic import Anthropic

client = Anthropic(api_key=userdata.get('ANTHROPIC_API_KEY'))
msg = client.messages.create(
    model="claude-sonnet-4-5",
    max_tokens=100,
    messages=[{"role": "user", "content": "Say hello in one short sentence."}],
)
print(msg.content[0].text)

# %%
from google.colab import userdata
from openai import OpenAI

client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))
resp = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Say hello in one short sentence."}],
    max_tokens=100,
)
print(resp.choices[0].message.content)

# %% [markdown]
# ## Resource inventory on Colab (§3.8)

# %%
# !nvidia-smi

# %%
import torch
print("cuda available:", torch.cuda.is_available())
